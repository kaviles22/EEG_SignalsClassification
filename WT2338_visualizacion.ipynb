# %%
import pandas as pd
import numpy as np
from numpy import array
datos=pd.read_csv(r'C:\Users\chris\OneDrive - Escuela Superior Politécnica del Litoral\ESPOL\Investigaciones\Proyectos\Wind Turbines\datasets\torvis\SCADA_data_WT2338.csv',header=0)

#print(datos.loc[0:3])
from datetime import datetime,timedelta
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
plt.figure(figsize=(25, 15))
plt.style.use('seaborn')

# %%
#print(datos)print(datos['id'])
datos.head()
# Out:
#         id  ld_id              date_time  fake_data  NumSampleTenMinBin  \
# 0  7015051   2338  2013-01-01 00:00:00.0          0                 600
# 1  7015052   2338  2013-01-01 00:10:00.0          0                 600
# 2  7015053   2338  2013-01-01 00:20:00.0          0                 600
# 3  7015054   2338  2013-01-01 00:30:00.0          0                 600
# 4  7015055   2338  2013-01-01 00:40:00.0          0                 600
#
#    AcumGralPala1Mean  AcumGralPala1Sdev  AcumGralPala1Min  AcumGralPala1Max  \
# 0                NaN                NaN               NaN               NaN
# 1                NaN                NaN               NaN               NaN
# 2                NaN                NaN               NaN               NaN
# 3                NaN                NaN               NaN               NaN
# 4                NaN                NaN               NaN               NaN
#
#    AcumGralPala2Mean  ...  VelRotorMin  VelRotorMax  VelVientoMean  \
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358134 entries, 0 to 358133
# Columns: 177 entries, id to YawMax
# dtypes: float64(172), int64(4), object(1)
# memory usage: 483.6+ MB

# %%
list(datos)
# Out:
# ['id',
#  'ld_id',
#  'date_time',
#  'fake_data',
#  'NumSampleTenMinBin',
#  'AcumGralPala1Mean',
#  'AcumGralPala1Sdev',
#  'AcumGralPala1Min',
#  'AcumGralPala1Max',
#  'AcumGralPala2Mean',
#  'AcumGralPala2Sdev',
#  'AcumGralPala2Min',
#  'AcumGralPala2Max',
#  'AcumGralPala3Mean',
#  'AcumGralPala3Sdev',
#  'AcumGralPala3Min',
#  'AcumGralPala3Max',
#  'AutopilotoCalc',
#  'CmdWTGMean',
#  'CmdWTGSdev',
#  'CmdWTGMin',
#  'CmdWTGMax',
#  'ConfirmContractGiroCCWMean',
#  'ConfirmContractGiroCCWSdev',
#  'ConfirmContractGiroCCWMin',
#  'ConfirmContractGiroCCWMax',
#  'ConfirmContractGiroCWMean',
#  'ConfirmContractGiroCWSdev',
#  'ConfirmContractGiroCWMin',
#  'ConfirmContractGiroCWMax',
#  'ContEnerActivaMean',
#  'ContEnerActivaSdev',
#  'ContEnerActivaMin',
#  'ContEnerActivaMax',
#  'CosPhiMean',
#  'CosPhiSdev',
#  'CosPhiMin',
#  'CosPhiMax',
#  'Diag1_R4Mean',
#  'Diag1_R4Sdev',
#  'Diag1_R4Min',
#  'Diag1_R4Max',
#  'EstadoCalc',
#  'FrecRedMean',
#  'FrecRedSdev',
# ...

# %%
x = range(358134)
list(x)
x = np.array(x)

df = pd.DataFrame({'Tiempo': x, 'date_time': datos['date_time'] ,'TempEjeLento_1': datos['TempEjeLento_1'], 'IndTurbulMean': datos['IndTurbulMean'], 'IndTurbulSdev': datos['IndTurbulSdev'], 'IndTurbulMin': datos['IndTurbulMin'],'IndTurbulMax': datos['IndTurbulMax'], 'TempAmbMean': datos['TempAmbMean'], 'TempAmbSdev': datos['TempAmbSdev'], 'TempAmbMin': datos['TempAmbMin'], 'TempAmbMax': datos['TempAmbMax']})
df
# Out:
#         Tiempo              date_time  TempEjeLento_1  IndTurbulMean  \
# 0            0  2013-01-01 00:00:00.0             NaN            NaN
# 1            1  2013-01-01 00:10:00.0             NaN            NaN
# 2            2  2013-01-01 00:20:00.0             NaN            NaN
# 3            3  2013-01-01 00:30:00.0             NaN            NaN
# 4            4  2013-01-01 00:40:00.0             NaN            NaN
# ...        ...                    ...             ...            ...
# 358129  358129  2019-10-28 00:10:00.0             NaN        2.87814
# 358130  358130  2019-10-28 00:20:00.0             NaN        2.80593
# 358131  358131  2019-10-28 00:30:00.0             NaN        2.57534
# 358132  358132  2019-10-28 00:40:00.0             NaN        2.70497
# 358133  358133  2019-10-28 00:50:00.0             NaN        2.81327
#
#         IndTurbulSdev  IndTurbulMin  IndTurbulMax  TempAmbMean  TempAmbSdev  \
# ...

# %% [markdown]
# # Visualización

# %%
df.TempEjeLento_1.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# La temperatura del eje lento tiene muchos valores negativos

# %%
df.IndTurbulMean.plot()
# Out:
# <AxesSubplot:>

# %%
df.IndTurbulSdev.plot()
# Out:
# <AxesSubplot:>

# %%
df.IndTurbulMin.plot()
# Out:
# <AxesSubplot:>

# %%
df.IndTurbulMax.plot()
# Out:
# <AxesSubplot:>

# %%
df.TempAmbMean.plot()
# Out:
# <AxesSubplot:>

# %%
df.TempAmbSdev.plot()
# Out:
# <AxesSubplot:>

# %%
df.TempAmbMin.plot()
# Out:
# <AxesSubplot:>

# %%
df.TempAmbMax.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Reemplazo posibles outliers por NaNs

# %%
df['IndTurbulMean'][df['IndTurbulMean']< 0] = None
df['IndTurbulMean'][df['IndTurbulMean']> 40] = None

df['IndTurbulSdev'][df['IndTurbulSdev']< 0] = None
df['IndTurbulSdev'][df['IndTurbulSdev']> 40] = None

df['IndTurbulMin'][df['IndTurbulMin']< 0] = None
df['IndTurbulMin'][df['IndTurbulMin']> 40] = None

df['IndTurbulMax'][df['IndTurbulMax']< 0] = None
df['IndTurbulMax'][df['IndTurbulMax']> 40] = None

df['TempAmbMean'][df['TempAmbMean']< -5] = None
df['TempAmbMean'][df['TempAmbMean']> 40] = None

df['TempAmbSdev'][df['TempAmbSdev']< -5] = None
df['TempAmbSdev'][df['TempAmbSdev']> 40] = None

df['TempAmbMin'][df['TempAmbMin']< -5] = None
df['TempAmbMin'][df['TempAmbMin']> 40] = None

df['TempAmbMax'][df['TempAmbMax']< -5] = None
df['TempAmbMax'][df['TempAmbMax']> 40] = None

df['TempEjeLento_1'][df['TempEjeLento_1']< 0] = None
df['TempEjeLento_1'][df['TempEjeLento_1']> 120] = None
# Out:
# C:\Users\chris\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\chris\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\chris\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
plt.figure(figsize=(30,9))

plt.subplot(221)
plt.plot(df['IndTurbulMean'])
plt.title('Indice Turbulencia')

plt.subplot(222)
plt.plot(df['IndTurbulSdev'])
plt.title('DevStd Turbulencia')

plt.subplot(223)
plt.plot(df['IndTurbulMin'])
plt.title('Turbulencia minima')

plt.subplot(224)
plt.plot(df['IndTurbulMax'])
plt.title('Turbulencia máxima')

plt.show()

# %%
plt.figure(figsize=(30,9))

plt.subplot(221)
plt.plot(df['TempAmbMean'])
plt.title('Temp Amb mean')

plt.subplot(222)
plt.plot(df['TempAmbSdev'])
plt.title('Tem Amb DesvStd')

plt.subplot(223)
plt.plot(df['TempAmbMin'])
plt.title('Temp Amb min')

plt.subplot(224)
plt.plot(df['TempAmbMax'])
plt.title('Temp Amb max')

plt.show()

# %%
df.TempEjeLento_1.plot()
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    Tiempo              date_time  TempEjeLento_1  IndTurbulMean  \
# 0       0  2013-01-01 00:00:00.0             NaN            NaN
# 1       1  2013-01-01 00:10:00.0             NaN            NaN
# 2       2  2013-01-01 00:20:00.0             NaN            NaN
# 3       3  2013-01-01 00:30:00.0             NaN            NaN
# 4       4  2013-01-01 00:40:00.0             NaN            NaN
#
#    IndTurbulSdev  IndTurbulMin  IndTurbulMax  TempAmbMean  TempAmbSdev  \
# 0            NaN           NaN           NaN          NaN          NaN
# 1            NaN           NaN           NaN          NaN          NaN
# 2            NaN           NaN           NaN          NaN          NaN
# 3            NaN           NaN           NaN          NaN          NaN
# 4            NaN           NaN           NaN          NaN          NaN
#
#    TempAmbMin  TempAmbMax
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# ...

# %% [markdown]
# Copia del dataset para poder comparar antes y despues de la interpolación

# %%
TempAmbMean=df.copy()
TempAmbMean=pd.DataFrame({'TempAmbMean': TempAmbMean['TempAmbMean']})
TempAmbMean.reset_index(drop=True, inplace=True)

# %% [markdown]
# Interpolo los missing values

# %%
df['IndTurbulMean']=df['IndTurbulMean'].interpolate(method='pchip',limit_area='inside')
df['IndTurbulMean']=df['IndTurbulMean'].fillna(method='bfill')
df['IndTurbulMean']=df['IndTurbulMean'].fillna(method='ffill')

df['IndTurbulSdev']=df['IndTurbulSdev'].interpolate(method='pchip',limit_area='inside')
df['IndTurbulSdev']=df['IndTurbulSdev'].fillna(method='bfill')
df['IndTurbulSdev']=df['IndTurbulSdev'].fillna(method='ffill')

df['IndTurbulMin']=df['IndTurbulMin'].interpolate(method='pchip',limit_area='inside')
df['IndTurbulMin']=df['IndTurbulMin'].fillna(method='bfill')
df['IndTurbulMin']=df['IndTurbulMin'].fillna(method='ffill')

df['IndTurbulMax']=df['IndTurbulMax'].interpolate(method='pchip',limit_area='inside')
df['IndTurbulMax']=df['IndTurbulMax'].fillna(method='bfill')
df['IndTurbulMax']=df['IndTurbulMax'].fillna(method='ffill')

df['TempAmbMean']=df['TempAmbMean'].interpolate(method='pchip',limit_area='inside')
df['TempAmbMean']=df['TempAmbMean'].fillna(method='bfill')
df['TempAmbMean']=df['TempAmbMean'].fillna(method='ffill')

df['TempAmbSdev']=df['TempAmbSdev'].interpolate(method='pchip',limit_area='inside')
df['TempAmbSdev']=df['TempAmbSdev'].fillna(method='bfill')
df['TempAmbSdev']=df['TempAmbSdev'].fillna(method='ffill')

df['TempAmbMin']=df['TempAmbMin'].interpolate(method='pchip',limit_area='inside')
df['TempAmbMin']=df['TempAmbMin'].fillna(method='bfill')
df['TempAmbMin']=df['TempAmbMin'].fillna(method='ffill')

df['TempAmbMax']=df['TempAmbMax'].interpolate(method='pchip',limit_area='inside')
df['TempAmbMax']=df['TempAmbMax'].fillna(method='bfill')
df['TempAmbMax']=df['TempAmbMax'].fillna(method='ffill')

df['TempEjeLento_1']=df['TempEjeLento_1'].interpolate(method='pchip',limit_area='inside')
df['TempEjeLento_1']=df['TempEjeLento_1'].fillna(method='bfill')
df['TempEjeLento_1']=df['TempEjeLento_1'].fillna(method='ffill')

# %%
df
# Out:
#         Tiempo              date_time  TempEjeLento_1  IndTurbulMean  \
# 0            0  2013-01-01 00:00:00.0         26.8217        2.33370
# 1            1  2013-01-01 00:10:00.0         26.8217        2.33370
# 2            2  2013-01-01 00:20:00.0         26.8217        2.33370
# 3            3  2013-01-01 00:30:00.0         26.8217        2.33370
# 4            4  2013-01-01 00:40:00.0         26.8217        2.33370
# ...        ...                    ...             ...            ...
# 358129  358129  2019-10-28 00:10:00.0         24.4292        2.87814
# 358130  358130  2019-10-28 00:20:00.0         24.4292        2.80593
# 358131  358131  2019-10-28 00:30:00.0         24.4292        2.57534
# 358132  358132  2019-10-28 00:40:00.0         24.4292        2.70497
# 358133  358133  2019-10-28 00:50:00.0         24.4292        2.81327
#
#         IndTurbulSdev  IndTurbulMin  IndTurbulMax  TempAmbMean  TempAmbSdev  \
# ...

# %% [markdown]
# Figuras para ver resultado

# %%
TempAmbMean2=df.copy()
TempAmbMean2=pd.DataFrame({'TempAmbMean': TempAmbMean2['TempAmbMean']})
TempAmbMean2.reset_index(drop=True, inplace=True)

def plotcharts():
    plt.figure(figsize=(20, 7))
    
    a = plt.plot(TempAmbMean2, 'blue', label='TempAmbMean2')
    plt.setp(a, markersize=0.1)


    
        
    plt.legend(loc=2)   
    plt.show()
plotcharts()

# %%
df.TempAmbMean.plot()
# Out:
# <AxesSubplot:>

# %%
df.TempEjeLento_1.iloc[0:180000].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Guardamos

# %%
df_temp=df.copy()
df_temp.reset_index(drop=True, inplace=True)

# %%
df_temp
# Out:
#         Tiempo              date_time  TempEjeLento_1  IndTurbulMean  \
# 0            0  2013-01-01 00:00:00.0         26.8217        2.33370
# 1            1  2013-01-01 00:10:00.0         26.8217        2.33370
# 2            2  2013-01-01 00:20:00.0         26.8217        2.33370
# 3            3  2013-01-01 00:30:00.0         26.8217        2.33370
# 4            4  2013-01-01 00:40:00.0         26.8217        2.33370
# ...        ...                    ...             ...            ...
# 358129  358129  2019-10-28 00:10:00.0         24.4292        2.87814
# 358130  358130  2019-10-28 00:20:00.0         24.4292        2.80593
# 358131  358131  2019-10-28 00:30:00.0         24.4292        2.57534
# 358132  358132  2019-10-28 00:40:00.0         24.4292        2.70497
# 358133  358133  2019-10-28 00:50:00.0         24.4292        2.81327
#
#         IndTurbulSdev  IndTurbulMin  IndTurbulMax  TempAmbMean  TempAmbSdev  \
# ...

# %% [markdown]
# Ver si existen saltos (vacios)

# %%
def myfunc1(df):
        lista=[]
        
        for i in range(1,len(df.Tiempo)):
            
             if df.Tiempo.loc[i] - df.Tiempo.loc[i-1] >1:
                    lista.append(i)
                    #lista.append(i)
                    

        return lista

# %%
lista=myfunc1(df_temp)
#Indices que no se pueden usar
lista = np.array(lista)
lista = lista - 1
lista
# Out:
# array([], dtype=float64)

# %% [markdown]
# no existen vacios

# %% [markdown]
# #### Variance Threshold - Remove Low Var Features
#
# Variance threshold method removes features whose variance below a pre-defined cutoff value. It is based on the notion that features that do not vary much within themselves have low predictive power. The main weakness of variance threshold is that it does not consider the relationship of input features with the output feature.
#
# It should be noted that, before performing variance thresholding, all features should be standardized so they will have the same scale.
#
# Scikit-learn provides VarianceThreshold function to perform variance threshold method.
#
# Variance Threshold Documentation: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.VarianceThreshold.html

# %%
df_features = df.drop('TempEjeLento_1', axis=1)

# %%
df_features = df_features.drop('Tiempo', axis=1)

# %%
df_features = df_features.drop('date_time', axis=1)

# %%
df_features.shape
# Out:
# (358134, 8)

# %%
df_features.head()
# Out:
#    IndTurbulMean  IndTurbulSdev  IndTurbulMin  IndTurbulMax  TempAmbMean  \
# 0         2.3337       0.470067       1.56249       3.66018      4.71226
# 1         2.3337       0.470067       1.56249       3.66018      4.71226
# 2         2.3337       0.470067       1.56249       3.66018      4.71226
# 3         2.3337       0.470067       1.56249       3.66018      4.71226
# 4         2.3337       0.470067       1.56249       3.66018      4.71226
#
#    TempAmbSdev  TempAmbMin  TempAmbMax
# 0     0.001143     4.71028     4.71424
# 1     0.001143     4.71028     4.71424
# 2     0.001143     4.71028     4.71424
# 3     0.001143     4.71028     4.71424
# 4     0.001143     4.71028     4.71424

# %%
from sklearn.feature_selection import VarianceThreshold

df_var = VarianceThreshold()

# Perform variance thresholding
df_var.fit_transform(df_features)

# Print the name and variance of each feature
for feature in zip(df_features.columns, df_var.variances_):
    print(feature)
# Out:
# ('IndTurbulMean', 3.7154086829090947)
# ('IndTurbulSdev', 0.22228134954780782)
# ('IndTurbulMin', 1.3563376807009029)
# ('IndTurbulMax', 10.093998572890385)
# ('TempAmbMean', 44.99143)
# ('TempAmbSdev', 0.15926564542381524)
# ('TempAmbMin', 44.94538)
# ('TempAmbMax', 44.94538)

# %% [markdown]
# Let's visualize the results by creating a bar chart:

# %%
# Create a bar chart for visualizing the variances
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(4,4))
plt.bar(x=df_features.columns, height=df_var.variances_, color='tomato')
plt.xticks(rotation='vertical')
plt.ylabel('Variance')
plt.title('Variance Comparison')

plt.show()

# %%
# Create VarianceThreshold object to perform variance thresholding
selector = VarianceThreshold(threshold=0.2)

# Transform the dataset according to variance thresholding
df_features_new = selector.fit_transform(df_features)

# Print the results
print('Number of features before variance thresholding: {}'.format(df_features.shape[1]))
print('Number of features after variance thresholding: {}'.format(df_features_new.shape[1]))
# Out:
# Number of features before variance thresholding: 8
# Number of features after variance thresholding: 7

# %%
df_features.head()
# Out:
#    IndTurbulMean  IndTurbulSdev  IndTurbulMin  IndTurbulMax  TempAmbMean  \
# 0         2.3337       0.470067       1.56249       3.66018      4.71226
# 1         2.3337       0.470067       1.56249       3.66018      4.71226
# 2         2.3337       0.470067       1.56249       3.66018      4.71226
# 3         2.3337       0.470067       1.56249       3.66018      4.71226
# 4         2.3337       0.470067       1.56249       3.66018      4.71226
#
#    TempAmbSdev  TempAmbMin  TempAmbMax
# 0     0.001143     4.71028     4.71424
# 1     0.001143     4.71028     4.71424
# 2     0.001143     4.71028     4.71424
# 3     0.001143     4.71028     4.71424
# 4     0.001143     4.71028     4.71424

# %%
df_features = df.drop('TempAmbSdev', axis=1)

# %% [markdown]
# # Correlation

# %%
correlated_features = set()
correlation_matrix = df_features.corr()

# %%
correlation_matrix
# Out:
#                   Tiempo  TempEjeLento_1  IndTurbulMean  IndTurbulSdev  \
# Tiempo          1.000000        0.137296       0.007143       0.032066
# TempEjeLento_1  0.137296        1.000000       0.102167       0.096475
# IndTurbulMean   0.007143        0.102167       1.000000       0.851655
# IndTurbulSdev   0.032066        0.096475       0.851655       1.000000
# IndTurbulMin   -0.016562        0.094593       0.943903       0.684057
# IndTurbulMax    0.020086        0.104747       0.955875       0.940630
# TempAmbMean    -0.028227        0.326381      -0.228883      -0.107801
# TempAmbMin     -0.029088        0.326484      -0.229218      -0.108958
# TempAmbMax     -0.027598        0.326266      -0.230628      -0.108964
#
#                 IndTurbulMin  IndTurbulMax  TempAmbMean  TempAmbMin  \
# Tiempo             -0.016562      0.020086    -0.028227   -0.029088
# TempEjeLento_1      0.094593      0.104747     0.326381    0.326484
# ...

# %%
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)

# %%
len(correlated_features)
# Out:
# 5

# %%
print(correlated_features)
# Out:
# {'TempAmbMax', 'IndTurbulMax', 'IndTurbulMin', 'TempAmbMin', 'IndTurbulSdev'}

# %%
df.drop(labels=correlated_features, axis=1, inplace=True)

# %%
df
# Out:
#         Tiempo              date_time  TempEjeLento_1  IndTurbulMean  \
# 0            0  2013-01-01 00:00:00.0         26.8217        2.33370
# 1            1  2013-01-01 00:10:00.0         26.8217        2.33370
# 2            2  2013-01-01 00:20:00.0         26.8217        2.33370
# 3            3  2013-01-01 00:30:00.0         26.8217        2.33370
# 4            4  2013-01-01 00:40:00.0         26.8217        2.33370
# ...        ...                    ...             ...            ...
# 358129  358129  2019-10-28 00:10:00.0         24.4292        2.87814
# 358130  358130  2019-10-28 00:20:00.0         24.4292        2.80593
# 358131  358131  2019-10-28 00:30:00.0         24.4292        2.57534
# 358132  358132  2019-10-28 00:40:00.0         24.4292        2.70497
# 358133  358133  2019-10-28 00:50:00.0         24.4292        2.81327
#
#         TempAmbMean  TempAmbSdev
# 0           4.71226     0.001143
# 1           4.71226     0.001143
# 2           4.71226     0.001143
# ...

# %%
df.to_csv('datos_limpios_2338.csv')
